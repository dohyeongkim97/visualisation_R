# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyeongkim97/visualisation_R/blob/master/submit_for_q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages(c('babynames', 'ggplot', 'mdsr', 'ggthemes', 'tidyverse', 'Hmisc'))
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘ggplot’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# also installing the dependencies ‘AsioHeaders’, ‘websocket’, ‘svglite’, ‘plogr’, ‘chromote’, ‘checkmate’, ‘downloader’, ‘kableExtra’, ‘RMariaDB’, ‘skimr’, ‘webshot2’, ‘gridExtra’, ‘htmlTable’, ‘viridis’, ‘Formula’

# %%
library(babynames)
library(ggplot2)
library(mdsr)
library(ggthemes)
library(tidyverse)
library(Hmisc)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     src, summarize
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units

# %%
baby =make_babynames_dist()
baby_joseph = filter(baby, sex=='M', name=='Joseph')

bar_blue = filter(baby_joseph, year==wtd.quantile(baby_joseph$year, baby_joseph$est_alive_today, probs=0.5))

# %%
bar_blue
# Out:
#   year sex name   n     prop       alive_prob count_thousands age_today
# 1 1975 M   Joseph 22142 0.01364239 0.941555   22.142          39
#   est_alive_today
# 1 20847.91

# %%
baby_joseph
# Out:
#     year sex name   n     prop       alive_prob count_thousands age_today
# 1   1900 M   Joseph  3714 0.02290712 0.000000    3.714          114
# 2   1901 M   Joseph  2766 0.02392837 0.000025    2.766          113
# 3   1902 M   Joseph  3098 0.02333710 0.000050    3.098          112
# 4   1903 M   Joseph  3121 0.02413281 0.000075    3.121          111
# 5   1904 M   Joseph  3291 0.02376036 0.000100    3.291          110
# 6   1905 M   Joseph  3302 0.02305254 0.000125    3.302          109
# 7   1906 M   Joseph  3527 0.02448099 0.000150    3.527          108
# 8   1907 M   Joseph  3844 0.02423906 0.000175    3.844          107
# 9   1908 M   Joseph  4162 0.02501683 0.000200    4.162          106
# 10  1909 M   Joseph  4348 0.02458344 0.000225    4.348          105
# 11  1910 M   Joseph  5228 0.02507182 0.000250    5.228          104
# 12  1911 M   Joseph  6488 0.02687711 0.003347    6.488          103
# 13  1912 M   Joseph 12062 0.02671794 0.006444   12.062          102
# ...

# %%
median_year = wtd.quantile(baby_joseph$year, baby_joseph$est_alive_today, probs = 0.5)
bar_blue = filter(baby_joseph, year == median_year)

# %%
ggplot(baby_joseph, aes(x = year)) +
  geom_bar(aes(y = est_alive_today), stat = "identity", fill = "lightblue", alpha = 0.5) +

  geom_line(aes(y = n / 1000), size = 1, color = "black") +

  geom_vline(xintercept = median_year, color = "blue", size = 1.5) +

  annotate("text", x = 1910, y = 35, label = "Number of Josephs\nborn each year", size = 5) +

  annotate("text", x = 1920, y = 10, label = "Number of Josephs\nborn each year\nestimated to be alive.",
           color = "blue", size = 5) +

  annotate("text", x = 1980, y = 32, label = "The median\nliving Josephs\nis 37 years old.", size = 5) +

  scale_y_continuous(name = NULL, sec.axis = sec_axis(~ . * 1000, name = "Number of Josephs born each year")) +
  labs(title = "Age Distribution of American Boys Named Joseph",
       subtitle = "By year of birth",
       x = NULL,
       y = "40k") +
  theme_minimal() +
  theme(
    plot.title = element_text(size = 20, face = "bold"),
    plot.subtitle = element_text(size = 16),
    axis.title.y.right = element_text(color = "black", size = 12),
    axis.text.y.right = element_text(size = 12)
  )
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %%
ggplot(baby_joseph, aes(x = year)) +

  geom_bar(aes(y = est_alive_today), stat = "identity", fill = "lightblue", alpha = 0.5) +


  geom_line(aes(y = n), size = 1, color = "black") +


  geom_vline(xintercept = median_year, color = "blue", size = 1.5) +


  annotate("text", x = 1910, y = 35000, label = "Number of Josephs\nborn each year", size = 5) +


  annotate("text", x = 1920, y = 10000, label = "Number of Josephs\nborn each year\nestimated to be alive.",
           color = "blue", size = 5) +


  annotate("text", x = 1980, y = 32000, label = "The median\nliving Josephs\nis 37 years old.", size = 5) +


  scale_y_continuous(name = "Number of Josephs born each year",
                     sec.axis = sec_axis(~ ., name = "Estimated Josephs still alive")) +
  labs(title = "Age Distribution of American Boys Named Joseph",
       subtitle = "By year of birth",
       x = NULL) +

  theme_minimal() +
  theme(
    plot.title = element_text(size = 20, face = "bold"),
    plot.subtitle = element_text(size = 16),
    axis.title.y = element_text(color = "black", size = 12),
    axis.title.y.right = element_text(color = "blue", size = 12),
    axis.text.y.right = element_text(size = 12)
  )
# Out:
# plot without title

# %%
10%%2
# Out:
# [1] 0

# %%
label_custom_format <- function(x) {
  ifelse(x == 40000, "40k", as.character(x / 1000 ))
}

label_year_format <- function(x) {
  if (x %% 100 == 0) {
    as.character(x)
  } else {
    paste0("'", substr(x, 3, 4))
  }
}



ggplot(baby_joseph, aes(x = year)) +
  geom_bar(aes(y = est_alive_today), stat = "identity", fill = "lightblue", alpha = 0.5) +

  geom_line(aes(y = n), size = 1, color = "black") +

  geom_vline(xintercept = median_year, color = "blue", size = 1.5) +

  annotate("text", x = 1910, y = 35000, label = "Number of Josephs\nborn each year", size = 5) +

  annotate("text", x = 1920, y = 10000, label = "Number of Josephs\nborn each year\nestimated to be alive.",
           color = "blue", size = 5) +

  annotate("text", x = 1980, y = 32000, label = "The median\nliving Josephs\nis 37 years old.", size = 5) +

  scale_y_continuous(name = "Number of Josephs born each year", labels = label_custom_format, limits = c(0, 40000)) +


  labs(title = "Age Distribution of American Boys Named Joseph",
       subtitle = "By year of birth",
       x = NULL) +

  theme_minimal() +
  theme(
    plot.title = element_text(size = 20, face = "bold"),
    plot.subtitle = element_text(size = 16),
    axis.title.y = element_text(color = "black", size = 12),
    axis.text.y = element_text(size = 12),
    axis.title.y.right = element_blank(),
    axis.text.y.right = element_blank()
  )
# Out:
# plot without title

# %%
label_custom_format <- function(x) {
  ifelse(x == 40000, "40k", as.character(x / 1000 * 10))
}

label_year_format <- function(x) {
  ifelse(x %% 100 == 0, as.character(x), paste0("'", substr(x, 3, 4)))
}

x_breaks <- seq(1900, 2010, by = 10)

ggplot(baby_joseph, aes(x = year)) +
  geom_bar(aes(y = est_alive_today), stat = "identity", fill = "lightblue", alpha = 0.5) +

  geom_line(aes(y = n), size = 1, color = "black") +

  geom_vline(xintercept = median_year, color = "blue", size = 1.5) +

  annotate("text", x = 1910, y = 35000, label = "Number of Josephs\nborn each year", size = 5) +

  annotate("text", x = 1920, y = 10000, label = "Number of Josephs\nborn each year\nestimated to be alive.",
           color = "blue", size = 5) +

  annotate("text", x = 1980, y = 32000, label = "The median\nliving Josephs\nis 37 years old.", size = 5) +

  scale_y_continuous(name = "Number of Josephs born each year", labels = label_custom_format, limits = c(0, 40000)) +

  scale_x_continuous(breaks = x_breaks, labels = label_year_format, limits = c(1900, 2010)) +

  labs(title = "Age Distribution of American Boys Named Joseph",
       subtitle = "By year of birth",
       x = NULL) +

  theme_minimal() +
  theme(
    plot.title = element_text(size = 20, face = "bold"),
    plot.subtitle = element_text(size = 16),
    axis.title.y = element_text(color = "black", size = 12),
    axis.text.y = element_text(size = 12),
    axis.text.x = element_text(size = 12),
    axis.title.y.right = element_blank(),
    axis.text.y.right = element_blank()
  )
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# plot without title

# %%
baby <- make_babynames_dist()
male_m25 <-baby %>% select(sex, name, age_today, est_alive_today) %>%
    filter(sex=="M") %>% group_by(name) %>% summarise(number_alive=sum(est_alive_today))
top_25_m_name<- c(male_m25 %>% arrange(desc(number_alive)) %>% slice(1:25) %>% select(name))$name

top_25<- baby %>% filter(name %in% top_25_m_name, est_alive_today>0 )%>%
  select(name,age_today,est_alive_today)%>% group_by(name)%>%
  summarise(q1=wtd.quantile(age_today,est_alive_today, probs = 0.25),
            q2=wtd.quantile(age_today,est_alive_today, probs = 0.5),
            q3=wtd.quantile(age_today,est_alive_today, probs = 0.75))%>%
  arrange(q2)

# %%
label_custom_format <- function(x) {
  ifelse(x == 40000, "40k", as.character(x / 1000 * 10))
}

label_year_format <- function(x) {
  ifelse(x %% 100 == 0, as.character(x), paste0("'", substr(x, 3, 4)))
}

x_breaks <- seq(1900, 2010, by = 10)

ggplot(baby_joseph, aes(x = year)) +
  geom_bar(aes(y = est_alive_today), stat = "identity", fill = "lightblue", alpha = 0.5) +
  geom_line(aes(y = n), size = 1, color = "black") +
  geom_vline(xintercept = median_year, color = "blue", size = 1.5) +

  # 추가 레이블 텍스트 및 위치 조정
  annotate("text", x = 1915, y = 35000, label = "Number of Josephs\nborn each year",
           size = 5, color = "black", hjust = 0) +
  annotate("text", x = 1925, y = 10000, label = "Number of Josephs\nborn each year\nestimated to be alive.",
           color = "blue", size = 5, hjust = 0) +
  annotate("text", x = 1978, y = 32000, label = "The median\nliving Josephs\nis 37 years old.",
           size = 5, hjust = 0) +

  # y축 커스텀 설정
  scale_y_continuous(name = "Number of Josephs born each year",
                     labels = label_custom_format, limits = c(0, 40000), expand = c(0, 0)) +

  # x축 커스텀 설정
  scale_x_continuous(breaks = x_breaks, labels = label_year_format, limits = c(1900, 2010), expand = c(0, 0)) +

  # 제목 및 서브타이틀 설정
  labs(title = "Age Distribution of American Boys Named Joseph",
       subtitle = "By year of birth",
       x = NULL, y = NULL) +

  # 테마 설정
  theme_minimal() +
  theme(
    plot.title = element_text(size = 20, face = "bold"),
    plot.subtitle = element_text(size = 16),
    axis.title.y = element_text(color = "black", size = 12),
    axis.text.y = element_text(size = 12),
    axis.text.x = element_text(size = 12),
    axis.title.y.right = element_blank(),
    axis.text.y.right = element_blank(),
    panel.grid.minor = element_blank()  # 세부 격자선 제거
  )
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# plot without title

# %%
baby_joseph
# Out:
#     year sex name   n     prop       alive_prob count_thousands age_today
# 1   1900 M   Joseph  3714 0.02290712 0.000000    3.714          114
# 2   1901 M   Joseph  2766 0.02392837 0.000025    2.766          113
# 3   1902 M   Joseph  3098 0.02333710 0.000050    3.098          112
# 4   1903 M   Joseph  3121 0.02413281 0.000075    3.121          111
# 5   1904 M   Joseph  3291 0.02376036 0.000100    3.291          110
# 6   1905 M   Joseph  3302 0.02305254 0.000125    3.302          109
# 7   1906 M   Joseph  3527 0.02448099 0.000150    3.527          108
# 8   1907 M   Joseph  3844 0.02423906 0.000175    3.844          107
# 9   1908 M   Joseph  4162 0.02501683 0.000200    4.162          106
# 10  1909 M   Joseph  4348 0.02458344 0.000225    4.348          105
# 11  1910 M   Joseph  5228 0.02507182 0.000250    5.228          104
# 12  1911 M   Joseph  6488 0.02687711 0.003347    6.488          103
# 13  1912 M   Joseph 12062 0.02671794 0.006444   12.062          102
# ...

# %%
highlight_year = 1975

# %%
options(repr.plot.width=11, repr.plot.height=8)

ggplot(baby_joseph, aes(x = year)) +
  # 생존 추정 막대
  geom_bar(aes(y = est_alive_today), stat = "identity", fill = "skyblue", alpha = 0.5) +


  geom_bar(data = baby_joseph %>% filter(year == highlight_year), aes(x = year, y = est_alive_today), stat = "identity", fill = "blue", alpha = 0.8) +


  # 매년 태어난 Josephs 수에 대한 라인 그래프
  geom_line(aes(y = n), size = 1, color = "black") +

  # 추가 레이블 텍스트 및 위치 조정
  annotate("text", x = 1930, y = 32000, label = "Number of Josephs\nborn each year",
           size = 4, color = "black") +
  annotate("text", x = 1924, y = 10800, label = "Number of Josephs\nborn each year\nestimated to be alive.",
           color = "blue", size = 4) +
  annotate("text", x = 2000, y = 37000, label = "The median\nliving Josephs\nis 37 years old.",
           size = 4) +
#   annotate('curve', x = 1975, y = 22000, xend = 1990, yend = 32050,
#     linewidth = 0.5, curvature = -0.5,
#     arrow = arrow(length = unit(0.5, 'cm')))

  geom_curve(aes(x = 1993, y = 38000, xend = 1975, yend = 22000),
             color = "gray42", size = 0.5, curvature = 0.5,
             arrow = arrow(length = unit(0.5, 'cm'))) +

  # y축 커스텀 설정
  scale_y_continuous(labels = label_custom_format, limits = c(0, 40000), expand = c(0, 0)) +

  # x축 커스텀 설정
  scale_x_continuous(breaks = x_breaks, labels = label_year_format, limits = c(1900, 2010), expand = c(0, 0)) +

  # 제목 및 서브타이틀 설정
  labs(title = "Age Distribution of American Boys Named Joseph",
       subtitle = "By year of birth",
       x = NULL, y = NULL,
       caption = 'SOURCE: SOCIAL SECURITY ADMINISTRATION') +

  # 테마 설정
  theme_fivethirtyeight() +
  theme(
    plot.title = element_text(size = 20, face = "bold"),
    plot.subtitle = element_text(size = 16),
    axis.title.y = element_text(color = "black", size = 12),
    axis.text.y = element_text(size = 12),
    axis.text.x = element_text(size = 12),
    axis.title.y.right = element_blank(),
    axis.text.y.right = element_blank(),
    panel.grid.minor = element_blank()  # 세부 격자선 제거
  )
# Out:
# Warning message in geom_curve(aes(x = 1993, y = 38000, xend = 1975, yend = 22000), :
# “All aesthetics have length 1, but the data has 111 rows.
# ℹ Please consider using `annotate()` or provide this layer with data containing
#   a single row.”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# plot without title
